# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data=np.array([0,5,10,15,0,10,5,10,0])
_=plt.plot(data)
plt.plot(data)

# %%
#to save
plt.plot(data)
_=plt.savefig('demo1.png')

# %%
x=np.array([12,34,54,23,45])
y=np.array([45,34,23,44,67])
_=plt.plot(x,y,'o--')

# %%
y=np.array([10,20,30,40,50,60,70,80])
x=np.array([1,1,2,2,3,3,4,4])
#x=np.array([1,2,3,4,5,6,7,8])
_=plt.plot(x,y)
