# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_theme(style='whitegrid')

# %%
pd.set_option('display.max_columns',None)

# %%
url='https://raw.githubusercontent.com/digipodium/Datasets/main/classfication/pokemon_type.csv'
df=pd.read_csv(url)
df.head()

# %% [markdown]
# # Selection of Column, column accessed as a key

# %%
df['Name']

# %% [markdown]
# # Or

# %%
df.Type_1

# %% [markdown]
# # Multiple column

# %%
cols=['Total','Attack','Defense']

# %%
print(cols)

# %%
df[['Name','Total']]

# %%
# cols, ax = plt.subplots(figsize=(6.5, 6.5))
# sns.despine(cols, left=True, bottom=True)

# %%
plt.figure(figsize=(20,5))
sns.barplot(x='Name',y='HP',data=df[:100])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # SOrt

# %%
plt.figure(figsize=(20,5))
sns.barplot(x='Name',y='HP',data=df.sort_values('HP')[-100:])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Please check markers and similar types

# %% [markdown]
# # Only For Numerical Columns relation

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='Attack',y='Defense',data=df,hue='Type_1')

# %% [markdown]
# # Violin and Lm Plot

# %%
sns.lmplot(x='Attack',y='Defense',data=df)

# %%
sns.violinplot(x='Attack',y='Defense',data=df)

# %%
plt.figure(figsize=(20,6))
sns.violinplot(x='Type_1',y='Attack',data=df)
# Out:
# <AxesSubplot:xlabel='Type_1', ylabel='Attack'>

# %%
plt.figure(figsize=(20,6))
sns.swarmplot(x='Type_1',y='Attack',data=df)
# Out:
# <AxesSubplot:xlabel='Type_1', ylabel='Attack'>

# %%
plt.figure(figsize=(20,6))
sns.swarmplot(x='Type_1',y='Attack',data=df,alpha=0.8)
# Out:
# <AxesSubplot:xlabel='Type_1', ylabel='Attack'>
