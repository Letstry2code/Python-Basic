# %%
from PIL import Image

# %% [markdown]
# # Absolute

# %%
im = Image.open(r'C:\Users\KumarCha05\Documents\GitHub\Python-Basic\Multimedia\Capture Error.PNG')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\KumarCha05\Documents\GitHub\Python-Basic\Multimedia\image_processing.ipynb Cell 3' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/KumarCha05/Documents/GitHub/Python-Basic/Multimedia/image_processing.ipynb#ch0000002?line=0'>1</a> im = Image.open(r'C:\Users\KumarCha05\Documents\GitHub\Python-Basic\Multimedia\Capture Error.PNG')
#
# NameError: name 'Image' is not defined

# %%
print(im)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=686x114 at 0x7FAB586B8490>

# %%
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=686x114>

# %%
im.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=686x114>

# %%
im.size
# Out:
# (686, 114)

# %%
w,h=im.size

# %%
w,h=im.size
print(f'resolution = {w} x {h} pixels')
# Out:
# resolution = 686 x 114 pixels

# %%
im.resize((100,200))
# Out:
# <PIL.Image.Image image mode=RGBA size=100x200>

# %%
# Half

im.resize((w//2,h//2))
# Out:
# <PIL.Image.Image image mode=RGBA size=343x57>

# %%
# double

im.resize((w*2,h*2))
# Out:
# <PIL.Image.Image image mode=RGBA size=1372x228>

# %%
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=686x114>

# %%
im.resize((w//4,h//4)).save('sample_small.png')

# %%
from PIL import ImageFilter
im = Image.open(r'/workspaces/Python-Basic/Capture Error.PNG')

# %%
im.filter(ImageFilter.CONTOUR)
# Out:
# <PIL.Image.Image image mode=RGBA size=686x114>

# %%
im.filter(ImageFilter.EDGE_ENHANCE)
# Out:
# <PIL.Image.Image image mode=RGBA size=686x114>

# %%
im.rotate(90)
# Out:
# <PIL.Image.Image image mode=RGBA size=686x114>

# %%
im.rotate(90,fillcolor='white')
# Out:
# <PIL.Image.Image image mode=RGBA size=686x114>

# %% [markdown]
# ##Used Widely

# %%
##Most  used

im.rotate(90,expand=True)
# Out:
# <PIL.Image.Image image mode=RGBA size=114x686>

# %%
from time import sleep
for i in range(5):
    im.rotate(90,expand=True).show()

    sleep(1)
# Out:
# <PIL.Image.Image image mode=RGBA size=114x686>
# <PIL.Image.Image image mode=RGBA size=114x686>
# <PIL.Image.Image image mode=RGBA size=114x686>
# <PIL.Image.Image image mode=RGBA size=114x686>
# <PIL.Image.Image image mode=RGBA size=114x686>

# %% [markdown]
# ## Blend 2 Images
# relative address

# %%
im1=Image.Open('../sample_small.png')
im2=Image.Open('../Capture Error.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /workspaces/Python-Basic/Multimedia/image_processing.ipynb Cell 24' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://codespaces%2Bletstry2code-python-basic-v67jv5qggf675/workspaces/Python-Basic/Multimedia/image_processing.ipynb#ch0000023vscode-remote?line=0'>1</a> im1=Image.Open('../sample_small.png')
#       <a href='vscode-notebook-cell://codespaces%2Bletstry2code-python-basic-v67jv5qggf675/workspaces/Python-Basic/Multimedia/image_processing.ipynb#ch0000023vscode-remote?line=1'>2</a> im2=Image.Open('../Capture Error.png')
#
# File /opt/python/3.10.4/lib/python3.10/site-packages/PIL/Image.py:108, in __getattr__(name)
#      95         warnings.warn(
#      96             name
#      97             + " is "
#    (...)
#     105             stacklevel=2,
#     106         )
#     107         return enum[name]
# ...

# %%
from PIL import Image

im1=Image.Open(r'/workspaces/Python-Basic/Multimedia/Capture Error.PNG')
im2=Image.Open(r'/workspaces/Python-Basic/Multimedia/sample_small.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /workspaces/Python-Basic/Multimedia/image_processing.ipynb Cell 25' in <cell line: 3>()
#       <a href='vscode-notebook-cell://codespaces%2Bletstry2code-python-basic-v67jv5qggf675/workspaces/Python-Basic/Multimedia/image_processing.ipynb#ch0000025vscode-remote?line=0'>1</a> from PIL import Image
# ----> <a href='vscode-notebook-cell://codespaces%2Bletstry2code-python-basic-v67jv5qggf675/workspaces/Python-Basic/Multimedia/image_processing.ipynb#ch0000025vscode-remote?line=2'>3</a> im1=Image.Open(r'/workspaces/Python-Basic/Multimedia/Capture Error.PNG')
#       <a href='vscode-notebook-cell://codespaces%2Bletstry2code-python-basic-v67jv5qggf675/workspaces/Python-Basic/Multimedia/image_processing.ipynb#ch0000025vscode-remote?line=3'>4</a> im2=Image.Open(r'/workspaces/Python-Basic/Multimedia/sample_small.png')
#
# ...

# %%
im2=im2.resize(im1.size)
print(im1.size,im2.size)

# %%
print(im1.mode, im2.mode)

# %%
im2=im2.convert('RGB')
print(im1.mode,im2.mode)

# %%
Image.blend(im1,im2,0.5)

## 0.5 can be used to change the imposing image dominance
